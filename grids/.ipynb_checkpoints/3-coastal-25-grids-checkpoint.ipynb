# %%
# coding: utf-8
__author__ = "Nicholas Metherall"
__copyright__ = "Copyright 2025, The Pacific Community (SPC)"
__license__ = "CreativeCommons"
__version__ = "0.1"
__email__ = "nicholasm@spc.int"
__status__ = "Development"

import os
os.environ['USE_PYGEOS'] = '0'
import pandas as pd
import geopandas as gpd
import numpy as np
from fiona.crs import from_epsg
import shapely
import warnings
from shapely.ops import unary_union
from shapely.geometry import box
warnings.filterwarnings('ignore')
# coastal ndti

# %%
coastline_lines = gpd.read_file("coastline_lines.geojson")
coastal_grids = gpd.read_file("coastal_macblue_grids.geojson")
coastal_grids.plot()
# Out:
# <Axes: >

# %%
coastal_grids
# Out:
#      level_1 GID_0           COUNTRY  index    uuid  index_right  \
# 0         16   FJI              Fiji      1    FJI1            0
# 1         17   VUT           Vanuatu      2    VUT2            0
# 2         17   FJI              Fiji      3    FJI3            0
# 3         18   VUT           Vanuatu      4    VUT4            0
# 4         18   VUT           Vanuatu      5    VUT5            0
# ..       ...   ...               ...    ...     ...          ...
# 201       40   PNG  Papua New Guinea    225  PNG225            0
# 202       40   PNG  Papua New Guinea    226  PNG226            0
# 203       40   PNG  Papua New Guinea    227  PNG227            0
# 204       40   PNG  Papua New Guinea    228  PNG228            0
# 205       40   PNG  Papua New Guinea    229  PNG229            0
#
#                                               geometry
# 0    POLYGON ((2853497.38 -2758834.497, 2860754.992...
# 1    POLYGON ((1820480.449 -2658691.923, 1824951.85...
# ...

# %%
def twentyfifths(grid):
    minx, miny, maxx, maxy = grid.bounds
    width = (maxx - minx) / 8
    height = (maxy - miny) / 8
    result = []
    idx = 1
    for i in range(8):
        for j in range(8):
            x1 = minx + i * width
            x2 = minx + (i + 1) * width
            y1 = miny + j * height
            y2 = miny + (j + 1) * height
            result.append((box(x1, y1, x2, y2), f'Q{idx}'))
            idx += 1
    return result

# Build a list of dicts for each sub-square
records = []
for idx, row in coastal_grids.iterrows():
    for geom, twentyfifth_name in twentyfifths(row.geometry):
        rec = row.to_dict()
        rec['geometry'] = geom
        rec['twentyfifth'] = twentyfifth_name
        records.append(rec)

twentyfifths_gdf = gpd.GeoDataFrame(records, crs=coastal_grids.crs)

# %%
twentyfifths_gdf['quid'] = twentyfifths_gdf['uuid']+twentyfifths_gdf['twentyfifth']+'_'+twentyfifths_gdf['level_1'].astype(str)

# %%
twentyfifths_gdf
# Out:
#        level_1 GID_0           COUNTRY  index    uuid  index_right  \
# 0           16   FJI              Fiji      1    FJI1            0
# 1           16   FJI              Fiji      1    FJI1            0
# 2           16   FJI              Fiji      1    FJI1            0
# 3           16   FJI              Fiji      1    FJI1            0
# 4           16   FJI              Fiji      1    FJI1            0
# ...        ...   ...               ...    ...     ...          ...
# 13179       40   PNG  Papua New Guinea    229  PNG229            0
# 13180       40   PNG  Papua New Guinea    229  PNG229            0
# 13181       40   PNG  Papua New Guinea    229  PNG229            0
# 13182       40   PNG  Papua New Guinea    229  PNG229            0
# 13183       40   PNG  Papua New Guinea    229  PNG229            0
#
#                                                 geometry twentyfifth  \
# 0      POLYGON ((2864407.221 -2758834.497, 2864407.22...          Q1
# ...

# %%
# Collect all new rows as dicts
records = []
for idx, row in twentyfifths_gdf.iterrows():
    for geom, twentyfifth_name in twentyfifths(row.geometry):
        rec = row.to_dict()
        rec['geometry'] = geom
        rec['twentyfifth'] = twentyfifth_name  # Optional: label the twentyfifth
        records.append(rec)

twentyfifths_gdf = gpd.GeoDataFrame(records, crs=coastal_grids.crs)

# %%
twentyfifths_gdf.plot()

# %%
twentyfifths_gdf

# %%
# Remove index_right if it exists
if 'index_right' in twentyfifths_gdf.columns:
    twentyfifths_gdf = twentyfifths_gdf.drop(columns='index_right')

if 'index_right' in coastline_lines.columns:
    coastline_lines = coastline_lines.drop(columns='index_right')

# %%
coastline_lines.plot()

# %%
# Only keep grids that intersect with any coastline
coastline_lines = gpd.read_file("coastline_lines.geojson")

subset = gpd.sjoin(twentyfifths_gdf, coastline_lines, how="inner", predicate="intersects")

# %%
subset

# %%
subset.plot()

# %%
twentyfifth_grids = subset
twentyfifth_grids.to_file("twentyfifth_grids.geojson")
