# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import requests
from dep_tools.grids import PACIFIC_EPSG
from fiona.io import ZipMemoryFile
from odc.geo.geom import Geometry
from odc.geo.xr import mask
from odc.stac import load
from pystac.client import Client
from xarray import DataArray, Dataset

# %%
site = "Kikori_sa2"

# %%
# aoi = gpd.read_file("priority_1_sites/subsample_sites/"f"{site}.geojson")

# %%
aoi = gpd.read_file("priority_1_sites/"f"{site}.geojson")

# %%
bbox = aoi.to_crs("EPSG:4326")

# %%
bounds_df = bbox.bounds
bounds_df
# Out:
#          minx      miny        maxx      maxy
# 0  144.941945 -7.578684  145.048294 -7.476573

# %%
values_array = bounds_df.values
flat_array = values_array.flatten()
bbox_int_list = flat_array.tolist()
bbox_tuple = tuple(bbox_int_list)

# %%
bbox = Geometry(bbox.geometry.values[0], crs=bbox.crs)

# %%
# bbox.explore()

# %%
# Get some seagrass data for the area
client = Client.open("https://stac.digitalearthpacific.org")
items = client.search(
    collections=["dep_s2_ammi"],
    intersects=bbox.json
).item_collection()

print(f"Found {len(items)} items")
# Out:
# Found 16 items

# %%
data = load(
    items,
    bbox=bbox_tuple,
    bands=["mangroves"],
    crs=PACIFIC_EPSG,  # 
    resolution=10,  # Change to 10 for full resolution,
    chunks={"x": 2048, "y": 2048}
)

# Convert data to 0 and 1, where 

data = data.mangroves != 255

data
# Out:
# <xarray.DataArray 'mangroves' (time: 8, y: 1140, x: 1185)> Size: 11MB
# dask.array<ne, shape=(8, 1140, 1185), dtype=bool, chunksize=(1, 1140, 1185), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 9kB -8.291e+05 -8.291e+05 ... -8.405e+05 -8.405e+05
#   * x            (x) float64 9kB -5.631e+05 -5.631e+05 ... -5.512e+05 -5.512e+05
#     spatial_ref  int32 4B 3832
#   * time         (time) datetime64[ns] 64B 2017-01-01 2018-01-01 ... 2024-01-01

# %%
def xarray_calculate_area(
    data: Dataset | DataArray,
    geom: Geometry,
    variable: str | None = None,
    value: int | float | None = None,
) -> float:
    # Work with a dataarray, not a dataset, so it's a singular thing
    if type(data) is not DataArray:
        if variable is None:
            raise ValueError("Variable must be specified when data is a Dataset.")
        data = data[variable]

    # Only select a specific value. This will convert to float, with nans
    if value is not None:
        data = data.where(data == value)

    # Mask out regions outsize the geometry
    masked = mask(data, geom.to_crs(data.odc.crs))

    # Count all the non-nan cells, and multiply by area
    count = float(masked.notnull().sum().values)
    one_pixel_area = abs(
        masked.odc.geobox.resolution.x * masked.odc.geobox.resolution.y
    )

    return float(count) * one_pixel_area

# %%
bbox.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83244ebfe88a55136195ff7c52af895f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83244ebfe88a55136195ff7c52af895f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83244ebfe88a55136195ff7c52af895f = L.map(
#                 &quot;map_83244ebfe88a55136195ff7c52af895f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6af5df7fe28e9fe46b1950730a0df58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6af5df7fe28e9fe46b1950730a0df58.addTo(map_83244ebfe88a55136195ff7c52af895f);
#
#
#
#         function geo_json_a2101d3c5ab07fa30da86be790451e2a_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a2101d3c5ab07fa30da86be790451e2a = L.geoJson(null, {
#                 onEachFeature: geo_json_a2101d3c5ab07fa30da86be790451e2a_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_a2101d3c5ab07fa30da86be790451e2a_add (data) {
#             geo_json_a2101d3c5ab07fa30da86be790451e2a
#                 .addData(data);
#         }
#             geo_json_a2101d3c5ab07fa30da86be790451e2a_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[144.94194464943126, -7.578683680528839], [144.94194464943126, -7.476572597529874], [145.04829403862777, -7.476572597529874], [145.04829403862777, -7.578683680528839], [144.94194464943126, -7.578683680528839]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_a2101d3c5ab07fa30da86be790451e2a.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_a2101d3c5ab07fa30da86be790451e2a.addTo(map_83244ebfe88a55136195ff7c52af895f);
#
#
#             map_83244ebfe88a55136195ff7c52af895f.fitBounds(
#                 [[-7.578683680528839, 144.94194464943126], [-7.476572597529874, 145.04829403862777]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Run the xarray_calculate_area per time step
results = []
for time in data.time:
    da = data.sel(time=time)
    area_m2 = xarray_calculate_area(da, bbox, variable="mangroves", value=1)
    # Year, in YYYY, area in m2, area in km2
    results.append({
        "time": pd.to_datetime(time.values).year,
        # "area_m2": area_m2,
        "ammi_ha": area_m2 / 10000
    })

df = pd.DataFrame(results)
# df

# %%
# Keep only the rows where year is NOT 2017
df = df[df['time'] != 2017]

# Reset the index so it starts at 0, 1, 2... again
df = df.reset_index(drop=True)

df
# Out:
#    time  ammi_ha
# 0  2018  1124.73
# 1  2019   297.84
# 2  2020   362.10
# 3  2021   348.79
# 4  2022   923.92
# 5  2023   646.84
# 6  2024   394.10

# %%
df = df.set_index('time')
df.plot.line()
# Out:
# <Axes: xlabel='time'>

# %%
data.plot.imshow(
    col="time",
    col_wrap=4,
    levels=[0, 1, 2],
    colors=["white", "darkgreen"],
)

# %%
# mangroves_2018 = data.isel(time=1)
# mangroves_2018 = mangroves_2018.astype("uint16")
# mangroves_2024 = data.isel(time=7)
# mangroves_2024 = mangroves_2024.astype("uint16")
# mangrove_change_2018_2024 = (mangroves_2024*-2) - mangroves_2018
# # mangrove_change_2018_2024.odc.write_cog("change_detection/mangroves_ammi_change_"f"{site}_2018_2024.tiff")

# %%
# # df = transposed_df
# df.columns.name = None
# df.columns = df.columns.astype(int)
# df.index.name = None
df
# Out:
#       ammi_ha
# time
# 2018  1124.73
# 2019   297.84
# 2020   362.10
# 2021   348.79
# 2022   923.92
# 2023   646.84
# 2024   394.10

# %%
# 1. Move 'time' and 'values' from index to columns
df_reset = df.reset_index()

# 2. Now you can set 'time' as the index
area_df = df_reset.set_index('time')

# 3. Transpose the NEW area_df (not the old df)
transposed_df = area_df.transpose()
transposed_df.index.name = None
transposed_df
# Out:
# time        2018    2019   2020    2021    2022    2023   2024
# ammi_ha  1124.73  297.84  362.1  348.79  923.92  646.84  394.1

# %%
# area_df = df.set_index('time')
transposed_df = df.transpose()
transposed_df.index.name = None
transposed_df
# Out:
# time        2018    2019   2020    2021    2022    2023   2024
# ammi_ha  1124.73  297.84  362.1  348.79  923.92  646.84  394.1

# %%
# # Keep everything from row 1 onwards
# # for rows
# # df = df.iloc[1:]
# ## for columns 
# # df = df.iloc[:, 1:]
# # Optional: Reset index again to start at 0
# df = df.reset_index(drop=True)

# df

# %%
# df_clean

# %%
# df_clean = df.set_index('time')
# df_clean.plot.line()

# %%
# df_clean.to_csv("change_detection/"f"{site}.csv")

# %%
# df.plot(x="ammi_ha", y="ammi_ha", marker="o", title=site, ylim=(0, df["ammi_ha"].max() * 1.1))

# %%
# for r in results:
#     print(f"{r['time']}: {r['ammi_ha']:.2f} km²")

# %%
# df

# %%
# mangrove_change_2018_2024 = data.mangrove.isel(time=7) - data.mangrove.isel(time=1)
