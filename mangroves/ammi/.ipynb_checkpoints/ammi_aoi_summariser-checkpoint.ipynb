# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import requests
from dep_tools.grids import PACIFIC_EPSG
from fiona.io import ZipMemoryFile
from odc.geo.geom import Geometry
from odc.geo.xr import mask
from odc.stac import load
from pystac.client import Client
from xarray import DataArray, Dataset

# %%
site = "Vonavona"

# %%
aoi = gpd.read_file("priority_1_sites/"f"{site}.geojson")

# %%
bbox = aoi.to_crs("EPSG:4326")

# %%
bounds_df = bbox.bounds
bounds_df
# Out:
#          minx      miny        maxx      maxy
# 0  156.998566 -8.363854  157.195526 -8.141485

# %%
values_array = bounds_df.values
flat_array = values_array.flatten()
bbox_int_list = flat_array.tolist()
bbox_tuple = tuple(bbox_int_list)

# %%
bbox = Geometry(bbox.geometry.values[0], crs=bbox.crs)

# %%
# bbox.explore()

# %%
# Get some seagrass data for the area
client = Client.open("https://stac.digitalearthpacific.org")
items = client.search(
    collections=["dep_s2_ammi"],
    intersects=bbox.json
).item_collection()

print(f"Found {len(items)} items")
# Out:
# Found 16 items

# %%
data = load(
    items,
    bbox=bbox_tuple,
    bands=["mangroves"],
    crs=PACIFIC_EPSG,  # 
    resolution=10,  # Change to 10 for full resolution,
    chunks={"x": 2048, "y": 2048}
)

# Convert data to 0 and 1, where 

data = data.mangroves != 255

data
# Out:
# <xarray.DataArray 'mangroves' (time: 8, y: 2486, x: 2194)> Size: 44MB
# dask.array<ne, shape=(8, 2486, 2194), dtype=bool, chunksize=(1, 2048, 2048), chunktype=numpy.ndarray>
# Coordinates:
#   * y            (y) float64 20kB -9.033e+05 -9.033e+05 ... -9.282e+05
#   * x            (x) float64 18kB 7.791e+05 7.791e+05 ... 8.01e+05 8.01e+05
#     spatial_ref  int32 4B 3832
#   * time         (time) datetime64[ns] 64B 2017-01-01 2018-01-01 ... 2024-01-01

# %%
def xarray_calculate_area(
    data: Dataset | DataArray,
    geom: Geometry,
    variable: str | None = None,
    value: int | float | None = None,
) -> float:
    # Work with a dataarray, not a dataset, so it's a singular thing
    if type(data) is not DataArray:
        if variable is None:
            raise ValueError("Variable must be specified when data is a Dataset.")
        data = data[variable]

    # Only select a specific value. This will convert to float, with nans
    if value is not None:
        data = data.where(data == value)

    # Mask out regions outsize the geometry
    masked = mask(data, geom.to_crs(data.odc.crs))

    # Count all the non-nan cells, and multiply by area
    count = float(masked.notnull().sum().values)
    one_pixel_area = abs(
        masked.odc.geobox.resolution.x * masked.odc.geobox.resolution.y
    )

    return float(count) * one_pixel_area

# %%
bbox.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1a051ea493b81feef52b478d550c5f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1a051ea493b81feef52b478d550c5f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1a051ea493b81feef52b478d550c5f4 = L.map(
#                 &quot;map_f1a051ea493b81feef52b478d550c5f4&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f391bb6b77bc7d110f8a40490801ddc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f391bb6b77bc7d110f8a40490801ddc1.addTo(map_f1a051ea493b81feef52b478d550c5f4);
#
#
#
#         function geo_json_58f85baaeba9c61f7459f32ce4f3489d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_58f85baaeba9c61f7459f32ce4f3489d = L.geoJson(null, {
#                 onEachFeature: geo_json_58f85baaeba9c61f7459f32ce4f3489d_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_58f85baaeba9c61f7459f32ce4f3489d_add (data) {
#             geo_json_58f85baaeba9c61f7459f32ce4f3489d
#                 .addData(data);
#         }
#             geo_json_58f85baaeba9c61f7459f32ce4f3489d_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[156.99856550272904, -8.363854371563557], [156.99856550272904, -8.141485460008504], [157.19552648003054, -8.141485460008504], [157.19552648003054, -8.363854371563557], [156.99856550272904, -8.363854371563557]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_58f85baaeba9c61f7459f32ce4f3489d.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_58f85baaeba9c61f7459f32ce4f3489d.addTo(map_f1a051ea493b81feef52b478d550c5f4);
#
#
#             map_f1a051ea493b81feef52b478d550c5f4.fitBounds(
#                 [[-8.363854371563557, 156.99856550272904], [-8.141485460008504, 157.19552648003054]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Run the xarray_calculate_area per time step
results = []
for time in data.time:
    da = data.sel(time=time)
    area_m2 = xarray_calculate_area(da, bbox, variable="mangroves", value=1)
    # Year, in YYYY, area in m2, area in km2
    results.append({
        "time": pd.to_datetime(time.values).year,
        # "area_m2": area_m2,
        "ammi_ha": area_m2 / 10000
    })

df = pd.DataFrame(results)
df
# Out:
#    time  ammi_ha
# 0  2017  2066.12
# 1  2018  2355.88
# 2  2019  1942.81
# 3  2020  2295.64
# 4  2021  2042.53
# 5  2022  2597.04
# 6  2023  1939.47
# 7  2024  2397.10

# %%
df = df.set_index('time')
df.plot.line()
# Out:
# <Axes: xlabel='time'>

# %%
data.plot.imshow(
    col="time",
    col_wrap=4,
    levels=[0, 1, 2],
    colors=["white", "darkgreen"],
)

# %%
mangroves_2018 = data.isel(time=1)
mangroves_2018 = mangroves_2018.astype("uint16")
mangroves_2024 = data.isel(time=7)
mangroves_2024 = mangroves_2024.astype("uint16")
mangrove_change_2018_2024 = (mangroves_2024*-2) - mangroves_2018
mangrove_change_2018_2024.odc.write_cog("change_detection/mangroves_ammi_change_"f"{site}_2018_2024.tiff")
# Out:
# PosixPath('change_detection/mangroves_ammi_change_Vonavona_2018_2024.tiff')

# %%
# area_df = df.set_index('time')
# transposed_df = df.transpose()
# transposed_df.index.name = None
# transposed_df

# %%
# df = transposed_df
# df.columns.name = None
# df.columns = df.columns.astype(int)
# df.index.name = None
# df

# %%
df

# %%
# Assuming 'transposed_df' is the DataFrame resulting from the previous transpose

# 1. Select the 'time' row index level and use it to set the column headers.
#    We use .iloc[0] because 'time' is the first row of data in the transposed result.
df.columns = df.iloc[0]

# 2. Drop the original 'time' index row (which is now the column header)
#    and keep only the area data (which is the second row, index position 1).
df_clean = df.iloc[1:].copy()

# 3. Clean up the formatting and index names
df_clean.columns.name = None
df_clean.index.name = None

# 4. Convert the column headers (years) from float to integer
df_clean.columns = df_clean.columns.astype(int)

# 5. Display the final result
df_clean

# %%
df_clean.to_csv("change_detection/"f"{site}.csv")

# %%
# df.plot(x="ammi_ha", y="ammi_ha", marker="o", title=site, ylim=(0, df["ammi_ha"].max() * 1.1))

# %%
# for r in results:
#     print(f"{r['time']}: {r['ammi_ha']:.2f} km²")

# %%
# df

# %%
# mangrove_change_2018_2024 = data.mangrove.isel(time=7) - data.mangrove.isel(time=1)
